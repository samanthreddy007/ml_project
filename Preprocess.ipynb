# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r'ML3.csv',encoding='gbk')
# Out:
# /Users/fanyujia/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (1,11,12,19,20,129,132,169,230) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#                 Site Participant_ID  RowNumber  session_id  age anagrams1  \
# 0  AshlandUniversity             10       2741         NaN  NaN       NaN
# 1  AshlandUniversity             11       2848         NaN  NaN       NaN
# 2  AshlandUniversity             12        170   7385046.0   19     party
# 3  AshlandUniversity             13        173   7385155.0   18     party
# 4  AshlandUniversity             14        179   7391990.0   18       NaN
#
#   anagrams2 anagrams3 anagrams4  attention   ...    V1st AvailFirst AvailSign  \
# 0       NaN       NaN       NaN        NaN   ...     NaN        NaN       NaN
# 1       NaN       NaN       NaN        NaN   ...     NaN        NaN       NaN
# 2     flata     coine     caleo        NaN   ...     1.0        2.0         -
# 3       NaN       NaN       NaN        NaN   ...     1.0        3.0         +
# 4       NaN       NaN       NaN        NaN   ...     0.0        0.0         -
#
# ...

# %%
df_1=df.drop(['Site','attention','attentioncorrect','RowNumber','session_id','anagrams1', 'anagrams2','anagrams3','anagrams4',
              'bestgrade1','worstgrade1','feedback','highpower','lowpower','Date.x','Experimenter','Notes','StartDate.x',
              'EndDate','session_date','DateComputer','TimeComputer','Date.y','StartDate.y'], axis=1)

# %%
df_1.head(10)
# Out:
#   Participant_ID  age backcount1 backcount10 backcount2 backcount3 backcount4  \
# 0             10  NaN        NaN         NaN        NaN        NaN        NaN
# 1             11  NaN        NaN         NaN        NaN        NaN        NaN
# 2             12   19        357         330        354        351        348
# 3             13   18        357         330        354        351        348
# 4             14   18        357         130        354        351        248
# 5             15   18        357         330        354        351        348
# 6             16   18        357         330        354        351        348
# 7             17   24        357         330        354        351        348
# 8             18  NaN        NaN         NaN        NaN        NaN        NaN
# 9             19   18        357         330        354        351        348
#
#   backcount5 backcount6 backcount7    ...    V1st AvailFirst AvailSign  \
# ...

# %%
df_2=df_1[(df_1['AttentionCheck'].isin(['Pass']))]

# %%
df_2.head(10)
# Out:
#    Participant_ID age backcount1 backcount10 backcount2 backcount3 backcount4  \
# 2              12  19        357         330        354        351        348
# 3              13  18        357         330        354        351        348
# 4              14  18        357         130        354        351        248
# 6              16  18        357         330        354        351        348
# 9              19  18        357         330        354        351        348
# 10             20  19        357         330        354        351        348
# 12             22  18        357         330        354        351        348
# 13             23  19        NaN         330        354        351        348
# 14             24  18        357         330        354        351        348
# 17             27  20        357         330        354        351        348
#
#    backcount5 backcount6 backcount7    ...    V1st AvailFirst AvailSign  \
# ...

# %%
df_2.to_csv('out1.csv',index=False)

# %%
df_3=df_2[(df_2['year'].isin(['1','2','3','4']))]

# %%
df_3=df_3[(df_3['ethnicity'].isin(['1','2','3','4','5','6','7']))]

# %%
df_3=df_3[(df_3['big5_01'].isin(['1','2','3','4','5','6','7']))]

# %%
df_3=df_3[(df_3['big5_02'].isin(['1','2','3','4','5','6','7']))]

# %%
df_3=df_3[(df_3['big5_03'].isin(['1','2','3','4','5','6','7']))]

# %%
df_3=df_3[(df_3['big5_04'].isin(['1','2','3','4','5','6','7']))]

# %%
df_3=df_3[(df_3['big5_05'].isin(['1','2','3','4','5','6','7']))]

# %%
df_3=df_3[(df_3['big5_06'].isin(['1','2','3','4','5','6','7']))]

# %%
df_3=df_3[(df_3['big5_07'].isin(['1','2','3','4','5','6','7']))]

# %%
df_3=df_3[(df_3['big5_08'].isin(['1','2','3','4','5','6','7']))]

# %%
df_3=df_3[(df_3['big5_09'].isin(['1','2','3','4','5','6','7']))]

# %%
df_3=df_3[(df_3['big5_10'].isin(['1','2','3','4','5','6','7']))]

# %%
df_3=df_3[(df_3['gender'].isin(['1','2']))]

# %%
df_3.to_csv('out2.csv',index=False)
